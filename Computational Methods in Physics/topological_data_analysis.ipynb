# %% [markdown]
# # Requirements

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.optimize import minimize

# %% [markdown]
# # Functions

# %%
def create_manifold(colormap, fig_size, function_name):
    # Defining the function with multiple local maxima and minima
    z = function_f(x_range, y_range, resolution,function_name)
    # Plotting
    fig = plt.figure(figsize=fig_size)
    ax = fig.add_subplot(111, projection = '3d')
    surf = ax.plot_surface(x, y, z, cmap=colormap)
    # Adding a color bar
    fig.colorbar(surf)
    # Setting labels
    ax.set_xlabel('X axis')
    ax.set_ylabel('Y axis')
    ax.set_zlabel('Z axis')
    # Showing the plot
    # plt.show()
    return fig

# %% [markdown]
# # Introduction

# %%
x_range = (-5, 5)
y_range = (-5, 5)
resolution = 400
# Creating a meshgrid
x = np.linspace(x_range[0], x_range[1], resolution)
y = np.linspace(y_range[0], y_range[1], resolution)
x, y = np.meshgrid(x, y)
# Defining the function 
fx = np.sin(x) * np.cos(y) + np.sin(np.sqrt(x**2 + y**2))

# %%
#
fig = create_manifold(colormap = 'viridis',fig_size = (12, 6),function_name = fx)

# %% [markdown]
# # References
#
# * https://www.youtube.com/watch?v=7G6k3SxqxZ4
# * https://nixtla.mintlify.app/statsforecast/docs/tutorials/multipleseasonalities.html
# * https://en.wikipedia.org/wiki/Topological_data_analysis
# * https://www.youtube.com/playlist?list=PLvVaDdaHGtpesn2DHUo6ete-1pPhT1xzj
# * https://agustinus.kristia.de/techblog/2019/02/22/optimization-riemannian-manifolds/
# * https://andbloch.github.io/Stochastic-Gradient-Descent-on-Riemannian-Manifolds/
